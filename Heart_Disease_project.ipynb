# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/heart.csv')
df.head(7)
df.tail(6)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1019      2   0     2       1
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.info
# Out:
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
df.shape
# Out:
# (1025, 14)

# %%
x=df['age']
x
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
y=df['chol']
y
# Out:
# 0       212
# 1       203
# 2       174
# 3       203
# 4       294
#        ...
# 1020    221
# 1021    258
# 1022    275
# 1023    254
# 1024    188
# Name: chol, Length: 1025, dtype: int64

# %%
x=[5,8,33,4,22]
sns.lineplot(x,color='orange')
# Out:
# <Axes: >

# %%
y=[22,89,76,67,45,88,33,42,84]
sns.lineplot(y,color='violet')
# Out:
# <Axes: >

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
a=df['sex']
b=df['restecg']
plt.scatter(a,b)
plt.xlabel('sex')
plt.ylabel('restecg')
# Out:
# Text(0, 0.5, 'restecg')

# %%
plt.bar(a,b,color='red')
# Out:
# <BarContainer object of 1025 artists>

# %%
x=df['sex']
plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x78eb51511300>,
# ...
# ...
#   Text(-0.5146585768159451, -0.9721761925236527, ''),
#   Text(-0.5103700302289116, -0.9744344165946419, ''),
#   Text(-0.5060715752051617, -0.9766737227802161, ''),
#   Text(-0.4974452738428857, -0.9810954079656966, ''),
#   Text(-0.48878034261756065, -0.9854409047074616, ''),
#   Text(-0.4800774544174904, -0.989709875549407, ''),
#   Text(-0.4757119875369404, -0.9918155599271743, ''),
#   Text(-0.4757119875369404, -0.9918155599271743, ''),
#   Text(-0.47133728507858497, -0.9939019889781632, ''),
#   Text(-0.4625605133318773, -0.998016919448839, ''),
#   Text(-0.4537478207508165, -1.0020543474103014, ''),
#   Text(-0.4493282179033074, -1.004043899735384, ''),
#   Text(-0.4493282179033074, -1.004043899735384, ''),
#   Text(-0.44489989169833555, -1.0060139593299933, ''),
#   Text(-0.4360174132737115, -1.0098954477182782, ''),
#   Text(-0.4315634335004612, -1.0118068011558794, ''),
# ...

# %%
y=df['slope']
plt.hist(y)
# Out:
# (array([ 74.,   0.,   0.,   0.,   0., 482.,   0.,   0.,   0., 469.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
x=df.drop('target',axis=1)
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
y=df['target']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
x_train.shape
# Out:
# (512, 13)

# %%
y_train.shape
# Out:
# (512,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
w=StandardScaler()
x_train=w.fit_transform(x_train)
x_train
# Out:
# array([[-1.51999569,  0.66196846,  1.05084285, ..., -0.72488544,
#         -0.74511006, -0.51851712],
#        [-1.406781  ,  0.66196846,  2.01333219, ...,  0.98544335,
#          1.16715234, -0.51851712],
#        [-0.27463408,  0.66196846,  0.08835351, ...,  0.98544335,
#          0.21102114, -0.51851712],
#        ...,
#        [ 1.19715692,  0.66196846,  2.01333219, ..., -0.72488544,
#          0.21102114, -0.51851712],
#        [ 1.42358631,  0.66196846, -0.87413582, ..., -0.72488544,
#         -0.74511006, -0.51851712],
#        [ 0.63108346,  0.66196846,  1.05084285, ..., -0.72488544,
#         -0.74511006, -0.51851712]])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
p=DecisionTreeClassifier()
p.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=p.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.35477582846003897

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[169, 259],
#        [ 72,  13]])

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
graphviz.Source(export_graphviz(p,feature_names=x.columns,filled=True))
